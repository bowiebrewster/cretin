# %%
import os, glob 
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# We use this notebook to search through the test folder's .gen files. Finding the most used keywords helps in prioritizing what functionality should be written first setc.

# %%
# finds most used follow up after "word"

# we open the file location
path = "/Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test"
os.chdir(path)

lis_hist = []
word = 'boundary'

def read_gen(word, complete_path):
    f = open(complete_path, "r")
    for line in f.readlines():
        lis = line.split()
        if len(lis)>0:
            if word in lis[0]:
                rest = " ".join(lis[1:])
                print(complete_path)
                lis_hist.append(line)
                #lis_hist.append(lis[1])

                
for folder in os.listdir():
    os.chdir(path+"/"+folder)
    # for every file that ends in .gen
    for file in glob.glob("*.gen"):
        read_gen(word, path+"/"+folder+"/"+file)


# turn it into a frequncy table and print highest to lowest 
letter_counts = Counter(lis_hist)
df = pd.DataFrame.from_dict(letter_counts, orient='index')
df = df.sort_values(by=[0], ascending = False)
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(df)
# Out:
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/hyd1d/hyd1d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/larsendf/larsendf.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/larsensn/larsensn.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lasfoam/lasfoam.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lasfoam/lasfoam.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lasfoam3/lasfoam.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lasfoam3/lasfoam.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lasfoam4/lasfoam.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lasfoam4/lasfoam.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lasfoam5/lasfoam.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lasfoam5/lasfoam.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lym1d/lym1d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lym2d/lym2d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lym2d/lym2d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lym3d/lym3d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lym3d/lym3d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lym3d/lym3d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/lym3d/lym3d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/mgdiff1d/mgdiff1d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/mgdiff1d/mgdiff1d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/mgdiff2d/mgdiff2d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/mgsn1d/mgsn1d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/noh1d/noh1d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/rad1d/rad1d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/rad1d/rad1d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/rad2d/rad2d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/rad2d/rad2d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/scat1d/scat1d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/scat2d/scat2d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/scat2d/scat2d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/scat3d/scat3d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/scat3d/scat3d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/scat3d/scat3d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/scat3d/scat3d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/sn1d/sn1d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/sn1d/sn1d.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/suolsen/suolsen.gen
# /Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test/suolsensn/suolsensn.gen
#                                                     0
# boundary radiation streaming 1. 0. N1 xfile 1 1.\n  8
# boundary radiation value 1 TB\n                     5
# boundary all mirror 1\n                             2
# boundary radiation milne N 0.\n                     1
# boundary radiation value N 0.\n                     1
# boundary radiation streaming  0.01 -1.58 K1 K1 ...  1
# boundary radiation streaming  0.01 -1.56 K1 K1 ...  1
# boundary radiation streaming -0.01 -1.58 K1 K1 ...  1
# boundary radiation streaming -0.01 -1.56 K1 K1 ...  1
# boundary radiation streaming 0. -1.58 K1 K1 L1 ...  1
# boundary radiation streaming 0. -1.56 K1 K1 L1 ...  1
# boundary radiation streaming -1. 0. N1 xfile 1 ...  1
# boundary radiation milne N N 1 LMAX 0.\n            1
# boundary radiation value 1 1 1 LMAX TB\n            1
# boundary diffusion value 1 1 1 2 TB\n               1
# boundary radiation milne N TB\n                     1
# boundary radiation reflecting N\n                   1
# boundary radiation streaming -0.707 1.58 K2 K2 ...  1
# boundary radiation streaming -0.707 1.56 K2 K2 ...  1
# boundary radiation streaming  0.707 1.58 K2 K2 ...  1
# boundary radiation streaming  0.707 1.56 K2 K2 ...  1
# boundary radiation streaming 0.707 1.58 K2 K2 L...  1
# boundary radiation streaming 0.707 1.56 K2 K2 L...  1
# boundary radiation streaming 0.707 0. N xfile 1...  1
# boundary radiation value N TB\n                     1
# boundary radiation milne 1 TB\n                     1

# %%
# finds most used command in a specific chapter f.e 'geometry'
path = "/Users/bowie/OneDrive/Desktop/recretincode/cretin.v2_19_test/test"
os.chdir(path)

lis_hist = []
chapter = 'Radiation'
str_id = "c ----------------------------------"
saves = []
def read_gen(word, complete_path):
    f = open(complete_path, "r")
    lines = f.readlines()
    reading = False
    for i in range(len(lines)-2):
        line_i, line_j, line_k = lines[i], lines[i+1], lines[i+2]
        if (str_id in line_i) and (str_id in line_k) and (chapter in line_j):
            reading = True
        if (str_id in line_i) and (str_id in line_k) and (chapter not in line_j):
            reading = False
        if reading:
            spt = line_i.split()
            if len(spt) > 0:
                saves.append(spt[0])


for folder in os.listdir():
    os.chdir(path+"/"+folder)
    for file in glob.glob("*.gen"):
        read_gen(word, path+"/"+folder+"/"+file)


letter_counts = Counter(saves)
df = pd.DataFrame.from_dict(letter_counts, orient='index')
df = df.sort_values(by=[0], ascending = False)
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    df = df.drop('c')
    try:
        df.drop(chapter.lower())
    except:
        pass
    print(df)
# Out:
#                  0
# ebins           46
# lbins           26
# angles          26
# line            25
# spectrum        24
# aprd             8
# alias            6
# linedefault      6
# energy           5
# spectral-group   4
# linetype         4
# stark            2
# resonance        2
# r2file           2
# joinline         1
# #ifdef           1
# #endif           1
# energy0          1
